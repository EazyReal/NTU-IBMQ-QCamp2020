# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
from qiskit_alcom_provider.alcom_provider import *
from qiskit_alcom_provider.bdd_backend import *
from qiskit_alcom_provider.alcom_job import *
from qiskit_alcom_provider.qasm_simulator_alcom import *

# %%
from qiskit import QuantumCircuit, execute
from qiskit import Aer, IBMQ
from qiskit.providers.aer.noise import NoiseModel

# Choose a real device to simulate from IBMQ provider
# provider = IBMQ.load_account()
# backend = provider.get_backend('ibmq_vigo')
# coupling_map = backend.configuration().coupling_map

# Generate an Aer noise model for device
# noise_model = NoiseModel.from_backend(backend)
# basis_gates = noise_model.basis_gates

# Generate 3-qubit GHZ state
num_qubits = 3
circ = QuantumCircuit(3, 3)
circ.h(0)
circ.cx(0, 1)
circ.cx(1, 2)
circ.measure([0, 1, 2], [0, 1 ,2])

# Perform noisy simulation
backend = Aer.get_backend('qasm_simulator')
job = execute(circ, backend
#              coupling_map=coupling_map,
#              noise_model=noise_model,
#              basis_gates=basis_gates,
             )
result = job.result()

print(result.get_counts())
# print(result.get_statevector())
# Out:
# {'000': 540, '111': 484}

# %%
from qiskit import QuantumCircuit, execute

from qiskit_alcom_provider import ALComProvider


# Generate 3-qubit GHZ state
num_qubits = 3
circ = QuantumCircuit(3, 3)
circ.h(0)
circ.cx(0, 1)
circ.cx(1, 2)
circ.measure([0, 1, 2], [0, 1 ,2])

# Perform noisy simulation
ALCom = ALComProvider()
backend = ALCom.get_backend('qasm_simulator')
job = execute(circ, backend)
result = job.result()

print(result.get_counts())
print(result.get_statevector())
# Out:
# {'00': 512, '11': 512}
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))

# %%
from qiskit.visualization import plot_histogram, plot_bloch_multivector
plot_histogram(result.get_counts())

# %%
plot_bloch_multivector(result.get_statevector(), title="Hinton Plot")

# %%
#from qiskit.result import Result
#isinstance(result, Result)

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
# %matplotlib inline

qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)

state = Statevector.from_instruction(qc)
plot_bloch_multivector(state, title="Bell Bloch Multivector")

# %%
result.to_dict()
# Out:
# {'counts': {'00': 512, '11': 512},
#  'statevector': [[0.70710678118, 0, 0, 0.70710678118], [0, 0, 0, 0]],
#  'job_id': '74ee7c70-d09a-4c6c-94e3-128570ef3fcd',
#  'date': '2020-09-09T21:35:47.651015',
#  'backend_name': 'qasm_simulator',
#  'backend_version': '0.0.1',
#  'time_taken': 0.0012841224670410156}

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.h(1)
qc.cx(0,1)
qc.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      ├───┤┌─┴─┐
# q_1: ┤ H ├┤ X ├
#      └───┘└───┘

# %%
# Let's see the result
statevector_backend = Aer.get_backend('statevector_simulator')
final_state = execute(qc,statevector_backend).result().get_statevector()
#array_to_latex(final_state, pretext="\\text{Statevector} = ", precision=1)
plot_bloch_multivector(final_state)

# %%
({'101':500}, [[0], [0]])
# Out:
# ({'101': 500}, [[0], [0]])

# %%
bell_result = {
    #'results': [],
    'counts': {
        '00': 512, 
        '11': 512,
    },
    'statevector': [
        [0.70710678118,0],
        [0,0],
        [0,0],
        [0.70710678118,0],
    ]
}
import json
json.dumps(bell_result)
# Out:
# '{"counts": {"00": 512, "11": 512}, "statevector": null}'

# %%
bell_result = {
    #'results': [],
    'counts': {
        '00': 512, 
        '11': 512,
    },
    'statevector':None
}
import json
json.dumps(bell_result)
